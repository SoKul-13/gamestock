# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import FunctionTransformer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
from pandas import set_option
from pandas import read_csv
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
import math
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from numpy import set_printoptions
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
#original (have to downgrade sklearns package to use): from sklearn.externals.six import StringIO 
from six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
#import pydotplus
from sklearn import tree
#import graphviz

from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve
from sklearn.ensemble import AdaBoostClassifier

import warnings

from sklearn.kernel_ridge import KernelRidge

warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, cross_val_score
from sklearn.svm import SVC
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import roc_auc_score, roc_curve, auc
from scipy import interpolate
import seaborn as sns
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Reading the dataset using read_csv
df = pd.read_csv("C:/Users/ksoha/OneDrive/Documents/GitHub/gamestock/v1/all_stocks_5yr.csv/all_stocks_5yr.csv")
#row/line 649041, col 45
#column labels: date,open,high,low,close,volume,Name
# Displaying the first five rows of the dataset
print(df.head())

# Plotting the data
plt.figure(figsize=(12, 6))  # Setting the figure size
sns.lineplot(data=df, x='Time', y='Height', label='Height', color='blue')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('Height')
plt.title('Height Over Time')

# Display the plot
plt.show()
# Out:
#    2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 0  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 1  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 2  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 3  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# 4  2013-02-15  13.93  14.61  13.93  14.50  15628000  AAL
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 14
#      12 # Plotting the data
#      13 plt.figure(figsize=(12, 6))  # Setting the figure size
# ---> 14 sns.lineplot(data=df, x='Time', y='Height', label='Height', color='blue')
#      16 # Adding labels and title
#      17 plt.xlabel('Time')
#
# File c:\Users\ksoha\OneDrive\Documents\GitHub\collegecourses\.conda\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Users\ksoha\OneDrive\Documents\GitHub\collegecourses\.conda\Lib\site-packages\seaborn\relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File c:\Users\ksoha\OneDrive\Documents\GitHub\collegecourses\.conda\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\ksoha\OneDrive\Documents\GitHub\collegecourses\.conda\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\ksoha\OneDrive\Documents\GitHub\collegecourses\.conda\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\ksoha\OneDrive\Documents\GitHub\collegecourses\.conda\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Time` for `x`. An entry with this name does not appear in `data`.

# %%
min_value, max_value = 0, 0
def calculate_velocity(data):
    return np.diff(data)  # Difference between consecutive data points

def calculate_amplitude(data):
    return (max_value - min_value)/2  # Absolute values of the data points

def find_min(data):
    min_value = np.min(data)
    return min_value
    
def find_max(data):
    max_value = np.max(data)
    return max_value

# %%
def read_file(file_path):
    with open(file_path, 'r') as file:
        data = [float(line.strip()) for line in file]
    return data

def process_files_in_folder(folder_path):
    # Get a list of all RIT and LIT files in the folder
    rit_files = [f for f in os.listdir(folder_path) if f.endswith('.rit')]
    lit_files = [f for f in os.listdir(folder_path) if f.endswith('.lit')]
    
    # Initialize an empty list to store results
    results = []

    # Ensure that the number of RIT and LIT files match
    '''if len(rit_files) != len(lit_files):
        raise ValueError("The number of RIT and LIT files must be the same")
    '''
    # Loop through the file lists and process each pair of files
    for rit_file, lit_file in zip(rit_files, lit_files):
        rit_file_path = os.path.join(folder_path, rit_file)
        lit_file_path = os.path.join(folder_path, lit_file)
        
        # Read the RIT and LIT files
        rit_data = read_file(rit_file_path)
        lit_data = read_file(lit_file_path)
        
        # Calculate velocity and amplitude for both RIT and LIT data
        rit_velocity = calculate_velocity(rit_data)
        lit_velocity = calculate_velocity(lit_data)
        
        rit_amplitude = calculate_amplitude(rit_data)
        lit_amplitude = calculate_amplitude(lit_data)
        
        # Find min and max values for both RIT and LIT data
        rit_min = find_min(rit_data)
        rit_max = find_max(rit_data)
        lit_min = find_min(lit_data)
        lit_max = find_max(lit_data)
        
        # Store the results in a dictionary
        result = {
            'file_name': rit_file,
            'RIT_velocity': rit_velocity.tolist(),  # Convert numpy array to list for storage
            'LIT_velocity': lit_velocity.tolist(),  # Convert numpy array to list for storage
            'RIT_amplitude': rit_amplitude.tolist(),  # Convert numpy array to list for storage
            'LIT_amplitude': lit_amplitude.tolist(),  # Convert numpy array to list for storage
            'RIT_min': rit_min,
            'RIT_max': rit_max,
            'LIT_min': lit_min,
            'LIT_max': lit_max
        }
        
        # Append the dictionary to the results list
        results.append(result)
    
    return results

# %%
def main():
    # Replace 'path_to_your_folder' with the actual path to your folder
    folder_path = 'C:/Users/ksoha/OneDrive/Documents/GitHub/collegecourses/pioneer/effect-of-deep-brain-stimulation-on-parkinsonian-tremor-1.0.0/effect-of-deep-brain-stimulation-on-parkinsonian-tremor-1.0.0/rofh'
    
    # Process the files and get the results
    results = process_files_in_folder(folder_path)
    
    # Convert results to a DataFrame for easier manipulation and display
    results_df = pd.DataFrame(results)
    
    # Display the results
    print(results_df.head())

# Run the main function
if __name__ == "__main__":
    main()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
